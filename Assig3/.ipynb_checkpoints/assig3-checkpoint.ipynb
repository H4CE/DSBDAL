# %%
import pandas as pd
import numpy as np
import math

# %%
df=pd.read_csv("nba.csv")
df
# Out:
#               Name            Team  Number Position   Age Height  Weight
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0  \
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
#dropping the rows with null values
df1=df
df1=df1.dropna()
df1.shape
# Out:
# (364, 9)

# %%
#dropping the columns with null values
df2=df
df2=df2.dropna(axis=1)
df2.shape
# Out:
# (458, 0)

# %%
#replacing the null values with mean ~ similarly replace with mode and median
df["Salary"].fillna(df["Salary"].mean(),inplace=True)
df["Salary"]=df["Salary"].astype("int64")

# %%
# Out:
#               Name            Team  Number Position   Age Height  Weight
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0  \
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College   Salary
# 0                Texas  7730337
# ...

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary        int64
# dtype: object

# %%
#applying the data transformation to the Salary field.
#very long range so applying something to make the range shorter 
# applying logarithmic transformation, but before that check if all values are not null and positive
df["Salary"]=np.log2(df["Salary"])

# %%
df["Salary"]=df["Salary"].astype("int64")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0  \
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College  Salary
# 0                Texas      22
# ...

# %%
norm_salaries=np.zeros(458)
for i in range(salaries.size):
    norm_salaries[i]= (salaries[i]-mini)/(maxi-mini)

# %%
df["Salary"]=pd.DataFrame(norm_salaries)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0  \
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College    Salary
# 0                Texas  0.308359
# ...

# %%
# z score norm
# newZValue= (oldValue-mean)/std
z_norm_salaries=np.zeros(458)
mean=salaries.mean()
std=salaries.std()
for i in range(458):
    z_norm_salaries[i]=(salaries[i]-mean)/std
z_norm_salaries
# Out:
# array([ 5.59609023e-01,  3.78563045e-01, -1.98871294e-08, -7.15882581e-01,
#         3.04868344e-02,  1.38704294e+00, -7.11557105e-01, -5.18887380e-01,
#        -5.84932283e-01, -2.73567775e-01, -4.40575334e-01,  4.01188851e-01,
#        -2.74639454e-01, -5.99373792e-01, -4.31328467e-01, -2.74639454e-01,
#        -7.74714676e-01, -6.47791217e-01, -6.79674161e-01,  2.82418682e-01,
#        -6.28442851e-01, -9.12471785e-01, -6.47791217e-01,  2.87712292e+00,
#        -7.17510449e-01, -7.54905662e-01, -7.48302722e-01, -7.54905662e-01,
#        -7.54905662e-01,  1.23897581e+00,  6.11868021e-01, -6.21536818e-01,
#        -9.32495910e-01,  3.49454974e+00,  4.96136732e-01, -7.74714676e-01,
#        -7.74714676e-01, -6.33768303e-01,  1.51300886e+00, -2.11755327e-01,
#        -1.37780385e-01, -3.93146257e-01, -6.21272095e-01, -7.54905662e-01,
#        -1.63306895e-01, -9.06039577e-01, -1.98871294e-08, -7.54905662e-01,
# ...

# %%
df["Salary"]=z_norm_salaries

# %%
df.Salary.min()
# Out:
# -0.9324959095883861

# %%
df.Salary.max()
# Out:
# 3.9063614130184585

# %%
df.Salary.mean()
# Out:
# -4.7026914143510996e-17

# %%
df.Salary.std()
# Out:
# 1.0
