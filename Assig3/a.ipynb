# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import seaborn as sns

# %%
# Out:
# [24698712,
#  2989740,
#  8939408,
#  14764139,
#  3105652,
#  7078599,
#  19426193,
#  18763311,
#  8228391,
#  10544987,
#  20839241,
#  19067864,
#  20774253,
#  18414294,
#  17911552,
#  7785298,
#  7776492,
#  1545928,
#  11061728,
#  14568227]

# %%
y=np.arange(len(x))

# %%
plt.scatter(x,y)

# %%
sns.histplot(x)
# Out:
# <Axes: ylabel='Count'>
